# %%
import requests
from instagramy import InstagramUser
API_KEY='d09b3615f5cbadecf57b52d0563072fc' #V4 auth
API_LINK="https://api.themoviedb.org/3"
API_READ_ACCESS_TOKEN='eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMDliMzYxNWY1Y2JhZGVjZjU3YjUyZDA1NjMwNzJmYyIsInN1YiI6IjYyYzI4YTZiZjFiNTcxMDA3Y2EwZWJlMiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZApKpmNxSaiQtQajw4VXI_Aw9mBAj2C8RafOHRliHXI'

# %% [markdown]
# #### Change the path

# %%
path=r"Cleaned2_with genre.xlsx"

# %%
import pandas as pd
df=pd.read_excel(path)

# %%
df.shape
# Out:
# (4101, 19)

# %%
df.head()
# Out:
#    Unnamed: 0                               movie_title  title_year  duration  \
# 0           0                                    Avatar      2009.0     178.0
# 1           1  Pirates of the Caribbean: At World's End      2007.0     169.0
# 2           2                                   Spectre      2015.0     148.0
# 3           3                     The Dark Knight Rises      2012.0     164.0
# 4           4                               John Carter      2012.0     132.0
#
#        director_name     genre1     genre2     actor_1_name  actor1_insta  \
# 0      James Cameron     Action  Adventure      CCH Pounder           NaN
# 1     Gore Verbinski  Adventure    Fantasy      Johnny Depp    28225408.0
# 2         Sam Mendes     Action  Adventure  Christoph Waltz      154783.0
# 3  Christopher Nolan     Action      Crime        Tom Hardy     9392965.0
# 4     Andrew Stanton     Action  Adventure     Daryl Sabara           NaN
#
# ...

# %% [markdown]
# ### To check if instagram API has blocked you or not hehe

# %%
user=InstagramUser('yoyo.nitrous')
user.number_of_followers
# Out:
# 243

# %% [markdown]
# Use different insta handle every time you run, else it might use old stored value. If it returns the number of followers without any error, the instagramy hasnt blocked you (yet).

# %% [markdown]
# ### Adding insta IDs to dataframe

# %%
#Give start and end rows
start=3130
end=df.shape[0]

# %%
for i in range(start,end):
    print(i,end=" ")
    try:
        #print("entered try1")
        name1= df['actor_1_name'][i]
        #print(name)
        params={'query':name1,'api_key':API_KEY}
        response=requests.get('https://api.themoviedb.org/3/search/person?api_key='+API_KEY+'&query='+name1)
        pythondata=response.json()
        results=pythondata.get('results')
        PersonID=results[0]['id']
        r=requests.get(API_LINK+'/person/'+str(PersonID)+'/external_ids?api_key='+API_KEY)
        data=r.json()
        results=data.get('results')
        instaID1=data['instagram_id']
        if(instaID1!=None):
            user=InstagramUser(instaID1)
            f1=user.number_of_followers
            #df['actor2_insta'][i]=user.get_followers
            #user=InstagramUser(InstaID1)
            df['actor1_insta'][i]=f1
        #print(name1,end=" ")
    except:
        pass
    
    try:
        #print("\nentered try2")
        name2=df['actor_2_name'][i]    
        params={'query':name2,'api_key':API_KEY}
        response=requests.get('https://api.themoviedb.org/3/search/person?api_key='+API_KEY+'&query='+name2)
        pythondata=response.json()
        results=pythondata.get('results')
        PersonID=results[0]['id']
        r=requests.get(API_LINK+'/person/'+str(PersonID)+'/external_ids?api_key='+API_KEY)
        data=r.json()
        results=data.get('results')
        instaID2=data['instagram_id']
        if(instaID1!=None):
            user=InstagramUser(instaID2)
            f2=user.number_of_followers
            #df['actor2_insta'][i]=user.get_followers
            #user=InstagramUser(InstaID1)
            df['actor1_insta'][i]=f2
        #print(name2)
    except:
        pass
# Out:
# 3130
# C:\Users\niran\AppData\Local\Temp/ipykernel_18284/1828913010.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actor1_insta'][i]=f1
# 3131 3132 3133 3134
# C:\Users\niran\AppData\Local\Temp/ipykernel_18284/1828913010.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actor1_insta'][i]=f2
# ...

# %% [markdown]
# Once this finishes running, run the code for finding if insta has blocked you. If no blocking, then GG, run the above code for next set of rows. <br> Else, scan the df using df.loc to find where updation has stopped

# %%
df.loc[3900:4000]
# Out:
#       Unnamed: 0                        movie_title  title_year  duration  \
# 3900        3900                        The Calling      2014.0     108.0
# 3901        3901           The Brave Little Toaster      1987.0      90.0
# 3902        3902                           Fantasia      1940.0     120.0
# 3903        3903              The French Connection      1971.0     104.0
# 3904        3904                             8 Days      2014.0      90.0
# ...          ...                                ...         ...       ...
# 3996        3996  No Man's Land: The Rise of Reeker      2008.0      88.0
# 3997        3997                            Highway      2002.0      97.0
# 3998        3998                   Small Apartments      2012.0      96.0
# 3999        3999                        Coffee Town      2013.0      87.0
# 4000        4000       The Ghastly Love of Johnny X      2012.0     106.0
#
#          director_name     genre1     genre2       actor_1_name  actor1_insta  \
# ...

# %% [markdown]
# If a lot of NaN values are seen even though those actors are available on instagram, then issue detected.

# %% [markdown]
# #### Once all rows have been parsed and insta IDs added, export the dataframe into and excel file. This is your dataset

# %%
#Change path
df.to_excel(r"Cleaned2_with genre.xlsx")

# %%
print(df.groupby(["actor_1_name"]))

# %%
df
# Out:
#                                    movie_title  title_year  duration  \
# 0                                       Avatar      2009.0     178.0
# 1     Pirates of the Caribbean: At World's End      2007.0     169.0
# 2                                      Spectre      2015.0     148.0
# 3                        The Dark Knight Rises      2012.0     164.0
# 4                                  John Carter      2012.0     132.0
# ...                                        ...         ...       ...
# 4096                                 Checkmate      2015.0      97.0
# 4097                              Jack Reacher      2012.0     130.0
# 4098                                   #Horror      2015.0     101.0
# 4099                              Wind Walkers      2015.0      93.0
# 4100           Snow White and the Seven Dwarfs      1937.0      83.0
#
#               director_name     genre1     genre2       actor_1_name  \
# ...

# %%
counts = df['actor_1_name'].value_counts()

# %%
print(counts)
# Out:
# Robert De Niro       47
# Johnny Depp          41
# Nicolas Cage         33
# Denzel Washington    30
# Liam Neeson          29
#                      ..
# Ronald Reagan         1
# James Callis          1
# Aasif Mandvi          1
# Taylor Cole           1
# Adriana Caselotti     1
# Name: actor_1_name, Length: 1523, dtype: int64

# %%
print(counts[0:10])
# Out:
# Robert De Niro       47
# Johnny Depp          41
# Nicolas Cage         33
# Denzel Washington    30
# Liam Neeson          29
# J.K. Simmons         29
# Matt Damon           29
# Bruce Willis         28
# Harrison Ford        26
# Bill Murray          26
# Name: actor_1_name, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categories = df['actor_1_name']
encoded_categories = le.fit_transform(categories)
print(encoded_categories)
# Out:
# [ 199  736  263 ... 1425 1257   14]

# %%
print(max(encoded_categories))
# Out:
# 1522

# %%
# Out:
# 0             CCH Pounder
# 1             Johnny Depp
# 2         Christoph Waltz
# 3               Tom Hardy
# 4            Daryl Sabara
#               ...
# 4096          Katrina Law
# 4097           Tom Cruise
# 4098       Timothy Hutton
# 4099      Rudy Youngblood
# 4100    Adriana Caselotti
# Name: actor_1_name, Length: 4101, dtype: object

# %%
df['Actor_name_classes']=encoded_categories

# %%
df['Actor_name_classes']
# Out:
# 0        199
# 1        736
# 2        263
# 3       1442
# 4        334
#         ...
# 4096     799
# 4097    1438
# 4098    1425
# 4099    1257
# 4100      14
# Name: Actor_name_classes, Length: 4101, dtype: int32

# %%
df.to_excel(r"Cleaned2_with genre.xlsx")

# %%
# Out:
# [1075 1719 1937 ...  187  811  242]
